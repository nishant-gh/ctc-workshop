# %%
# !pip install -q google-adk
# Out:
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import os
try:
    from google.colab import userdata
    os.environ["GOOGLE_API_KEY"] = userdata.get("GOOGLE_API_KEY")
except ImportError:
    pass  # Not running in Colab; uses env var already set

# %%
from google.adk.agents import Agent, SequentialAgent
from google.adk.runners import InMemoryRunner
from google.genai import types

# %% [markdown]
# # Multi-Agent Systems with Google ADK
#
# So far we've built single agents — one LLM with tools. But complex tasks often need **multiple agents** working together, each with their own specialty.
#
# Google ADK supports this with **sub-agents**. Two key patterns:
#
# | Pattern | How it works | When to use |
# |---|---|---|
# | **SequentialAgent** | Runs sub-agents in order, like a pipeline | Fixed workflows (fetch → analyze → report) |
# | **LLM Coordinator** | A parent agent delegates to sub-agents based on the user's request | Routing / helpdesk / triage scenarios |
#
# We'll build both in this notebook.
#
# ---
#
# ## Part 1: Analytics Report Generator (Sequential Pipeline)
#
# We'll build a 3-stage pipeline:
#
# ```
# DataFetcher → Analyzer → ReportWriter
# ```
#
# Each agent writes its output to shared state via `output_key`, and the next agent picks it up.

# %% [markdown]
# ### Fake sales data

# %%
SALES_DATA = {
    "2024-Q3": [
        {"product": "Widget A", "units": 1200, "revenue": 36000},
        {"product": "Widget B", "units": 800, "revenue": 48000},
        {"product": "Gadget X", "units": 450, "revenue": 67500},
        {"product": "Gadget Y", "units": 300, "revenue": 27000},
    ],
    "2024-Q4": [
        {"product": "Widget A", "units": 1400, "revenue": 42000},
        {"product": "Widget B", "units": 950, "revenue": 57000},
        {"product": "Gadget X", "units": 520, "revenue": 78000},
        {"product": "Gadget Y", "units": 280, "revenue": 25200},
    ],
}

# %% [markdown]
# ### Tools for each agent

# %%
# --- DataFetcher tools ---

def get_sales_data(quarter: str) -> str:
    """Fetch sales data for a given quarter (e.g. '2024-Q3'). Returns a list of product sales records."""
    data = SALES_DATA.get(quarter)
    if data:
        return str(data)
    return f"No data found for {quarter}. Available quarters: {list(SALES_DATA.keys())}"


def list_available_quarters() -> str:
    """List all quarters that have sales data available."""
    return str(list(SALES_DATA.keys()))


# --- Analyzer tools ---

def compute_growth(current_quarter: str, previous_quarter: str) -> str:
    """Compute revenue growth rate between two quarters. Returns per-product and total growth."""
    curr = SALES_DATA.get(current_quarter)
    prev = SALES_DATA.get(previous_quarter)
    if not curr or not prev:
        return "One or both quarters not found."
    prev_map = {r["product"]: r["revenue"] for r in prev}
    results = []
    for r in curr:
        old = prev_map.get(r["product"], 0)
        growth = ((r["revenue"] - old) / old * 100) if old else 0
        results.append(f"{r['product']}: ${old:,} → ${r['revenue']:,} ({growth:+.1f}%)")
    total_prev = sum(r["revenue"] for r in prev)
    total_curr = sum(r["revenue"] for r in curr)
    total_growth = (total_curr - total_prev) / total_prev * 100
    results.append(f"TOTAL: ${total_prev:,} → ${total_curr:,} ({total_growth:+.1f}%)")
    return "\n".join(results)


def find_top_products(quarter: str, metric: str) -> str:
    """Find top products for a quarter ranked by a metric ('revenue' or 'units'). Returns ranked list."""
    data = SALES_DATA.get(quarter)
    if not data:
        return f"No data for {quarter}"
    if metric not in ("revenue", "units"):
        return "Metric must be 'revenue' or 'units'"
    ranked = sorted(data, key=lambda r: r[metric], reverse=True)
    return "\n".join(f"{i+1}. {r['product']}: {r[metric]:,} {metric}" for i, r in enumerate(ranked))


# --- ReportWriter has no tools (just writes from context) ---

# %% [markdown]
# ### Define the 3 sub-agents

# %%
data_fetcher = Agent(
    model="gemini-3-flash-preview",
    name="data_fetcher",
    instruction="""You are a data fetcher. Your job is to retrieve sales data.

1. First list available quarters.
2. Then fetch sales data for ALL available quarters.
3. Compile everything you retrieved into your response.""",
    tools=[get_sales_data, list_available_quarters],
    output_key="fetched_data",
)

analyzer = Agent(
    model="gemini-3-flash-preview",
    name="analyzer",
    instruction="""You are a data analyst. The fetched sales data is here:
{fetched_data}

Analyze it:
1. Compute growth between the two quarters using the compute_growth tool.
2. Find top products by revenue for the latest quarter.
3. Summarize your findings.""",
    tools=[compute_growth, find_top_products],
    output_key="analysis",
)

report_writer = Agent(
    model="gemini-3-flash-preview",
    name="report_writer",
    instruction="""You are a report writer. Using the analysis below, write a concise executive summary.

Analysis:
{analysis}

Format the report with:
- A headline with the quarter
- Key metrics (total revenue, growth rate)
- Top performing products
- One actionable recommendation

Keep it under 200 words.""",
    output_key="report",
)

# %% [markdown]
# ### Wire into a SequentialAgent pipeline

# %%
pipeline = SequentialAgent(
    name="analytics_pipeline",
    sub_agents=[data_fetcher, analyzer, report_writer],
)

# %% [markdown]
# ### Run the pipeline

# %%
runner = InMemoryRunner(agent=pipeline, app_name="analytics_pipeline")
runner.auto_create_session = True
user_content = types.Content(
    role="user",
    parts=[types.Part.from_text(text="Generate a quarterly analytics report.")],
)

final_text = ""
async for event in runner.run_async(user_id="user1", session_id="session1", new_message=user_content):
    if event.content and event.content.parts:
        for part in event.content.parts:
            if part.text:
                final_text = part.text

print(final_text)
# Out:
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File ~/repos/stage/ctc-workshop/.venv/lib/python3.11/site-packages/google/adk/models/google_llm.py:245, in Gemini.generate_content_async(self, llm_request, stream)
#     244 else:
# --> 245   response = await self.api_client.aio.models.generate_content(
#     246       model=llm_request.model,
#     247       contents=llm_request.contents,
#     248       config=llm_request.config,
#     249   )
#     250   logger.info('Response received from the model.')
#
# File ~/repos/stage/ctc-workshop/.venv/lib/python3.11/site-packages/google/genai/models.py:7498, in AsyncModels.generate_content(self, model, contents, config)
#    7491     logger.warning(
#    7492         'Tools at indices [%s] are not compatible with automatic function '
#    7493         'calling (AFC). AFC is disabled. If AFC is intended, please '
#    (...)   7496         indices_str,
#    7497     )
# -> 7498   return await self._generate_content(
#    7499       model=model, contents=contents, config=parsed_config
#    7500   )
#    7501 remaining_remote_calls_afc = _extra_utils.get_max_remote_calls_afc(
#    7502     parsed_config
#    7503 )
#
# File ~/repos/stage/ctc-workshop/.venv/lib/python3.11/site-packages/google/genai/models.py:6265, in AsyncModels._generate_content(self, model, contents, config)
#    6263 request_dict = _common.encode_unserializable_types(request_dict)
# -> 6265 response = await self._api_client.async_request(
#    6266     'post', path, request_dict, http_options
#    6267 )
#    6269 if config is not None and getattr(
#    6270     config, 'should_return_http_response', None
#    6271 ):
#
# File ~/repos/stage/ctc-workshop/.venv/lib/python3.11/site-packages/google/genai/_api_client.py:1447, in BaseApiClient.async_request(self, http_method, path, request_dict, http_options)
#    1443 http_request = self._build_request(
#    1444     http_method, path, request_dict, http_options
#    1445 )
# -> 1447 result = await self._async_request(
#    1448     http_request=http_request, http_options=http_options, stream=False
#    1449 )
#    1450 response_body = result.response_stream[0] if result.response_stream else ''
#
# File ~/repos/stage/ctc-workshop/.venv/lib/python3.11/site-packages/google/genai/_api_client.py:1380, in BaseApiClient._async_request(self, http_request, http_options, stream)
#    1379     return await retry(self._async_request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1380 return await self._async_retry(  # type: ignore[no-any-return]
#    1381     self._async_request_once, http_request, stream
#    1382 )
#
# File ~/repos/stage/ctc-workshop/.venv/lib/python3.11/site-packages/tenacity/asyncio/__init__.py:112, in AsyncRetrying.__call__(self, fn, *args, **kwargs)
#     111 while True:
# --> 112     do = await self.iter(retry_state=retry_state)
#     113     if isinstance(do, DoAttempt):
#
# File ~/repos/stage/ctc-workshop/.venv/lib/python3.11/site-packages/tenacity/asyncio/__init__.py:157, in AsyncRetrying.iter(self, retry_state)
#     156 for action in self.iter_state.actions:
# --> 157     result = await action(retry_state)
#     158 return result
#
# File ~/repos/stage/ctc-workshop/.venv/lib/python3.11/site-packages/tenacity/_utils.py:111, in wrap_to_async_func.<locals>.inner(*args, **kwargs)
#     110 async def inner(*args: typing.Any, **kwargs: typing.Any) -> typing.Any:
# --> 111     return call(*args, **kwargs)
#
# File ~/repos/stage/ctc-workshop/.venv/lib/python3.11/site-packages/tenacity/__init__.py:413, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     412 if self.reraise:
# --> 413     raise retry_exc.reraise()
#     414 raise retry_exc from fut.exception()
#
# File ~/repos/stage/ctc-workshop/.venv/lib/python3.11/site-packages/tenacity/__init__.py:184, in RetryError.reraise(self)
#     183 if self.last_attempt.failed:
# --> 184     raise self.last_attempt.result()
#     185 raise self
#
# File ~/.local/share/uv/python/cpython-3.11.12-macos-aarch64-none/lib/python3.11/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#
# File ~/.local/share/uv/python/cpython-3.11.12-macos-aarch64-none/lib/python3.11/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File ~/repos/stage/ctc-workshop/.venv/lib/python3.11/site-packages/tenacity/asyncio/__init__.py:116, in AsyncRetrying.__call__(self, fn, *args, **kwargs)
#     115 if is_async:
# --> 116     result = await fn(*args, **kwargs)
#     117 else:
#
# File ~/repos/stage/ctc-workshop/.venv/lib/python3.11/site-packages/google/genai/_api_client.py:1360, in BaseApiClient._async_request_once(self, http_request, stream)
#    1353 client_response = await self._async_httpx_client.request(
#    1354     method=http_request.method,
#    1355     url=http_request.url,
#    (...)   1358     timeout=http_request.timeout,
#    1359 )
# -> 1360 await errors.APIError.raise_for_async_response(client_response)
#    1361 return HttpResponse(client_response.headers, [client_response.text])
#
# File ~/repos/stage/ctc-workshop/.venv/lib/python3.11/site-packages/google/genai/errors.py:216, in APIError.raise_for_async_response(cls, response)
#     214     raise ValueError(f'Unsupported response type: {type(response)}')
# --> 216 await cls.raise_error_async(status_code, response_json, response)
#
# File ~/repos/stage/ctc-workshop/.venv/lib/python3.11/site-packages/google/genai/errors.py:238, in APIError.raise_error_async(cls, status_code, response_json, response)
#     237 if 400 <= status_code < 500:
# --> 238   raise ClientError(status_code, response_json, response)
#     239 elif 500 <= status_code < 600:
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-3-flash\nPlease retry in 49.180331848s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-3-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '49s'}]}}
#
# The above exception was the direct cause of the following exception:
#
# _ResourceExhaustedError                   Traceback (most recent call last)
# Cell In[8], line 9
#       3 user_content = types.Content(
#       4     role="user",
#       5     parts=[types.Part.from_text(text="Generate a quarterly analytics report.")],
#       6 )
#       8 final_text = ""
# ----> 9 async for event in runner.run_async(user_id="user1", session_id="session1", new_message=user_content):
#      10     if event.content and event.content.parts:
#      11         for part in event.content.parts:
#
# File ~/repos/stage/ctc-workshop/.venv/lib/python3.11/site-packages/google/adk/runners.py:565, in Runner.run_async(self, user_id, session_id, invocation_id, new_message, state_delta, run_config)
#     557       await _run_compaction_for_sliding_window(
#     558           self.app,
#     559           session,
#     560           self.session_service,
#     561           skip_token_compaction=invocation_context.token_compaction_checked,
#     562       )
#     564 async with Aclosing(_run_with_trace(new_message, invocation_id)) as agen:
# --> 565   async for event in agen:
#     566     yield event
#
# File ~/repos/stage/ctc-workshop/.venv/lib/python3.11/site-packages/google/adk/runners.py:550, in Runner.run_async.<locals>._run_with_trace(new_message, invocation_id)
#     540       yield event
#     542 async with Aclosing(
#     543     self._exec_with_plugin(
#     544         invocation_context=invocation_context,
#    (...)    548     )
#     549 ) as agen:
# --> 550   async for event in agen:
#     551     yield event
#     552 # Run compaction after all events are yielded from the agent.
#     553 # (We don't compact in the middle of an invocation, we only compact at
#     554 # the end of an invocation.)
#
# File ~/repos/stage/ctc-workshop/.venv/lib/python3.11/site-packages/google/adk/runners.py:782, in Runner._exec_with_plugin(self, invocation_context, session, execute_fn, is_live_call)
#     779 is_transcribing: bool = False
#     781 async with Aclosing(execute_fn(invocation_context)) as agen:
# --> 782   async for event in agen:
#     783     _apply_run_config_custom_metadata(
#     784         event, invocation_context.run_config
#     785     )
#     786     if is_live_call:
#
# File ~/repos/stage/ctc-workshop/.venv/lib/python3.11/site-packages/google/adk/runners.py:539, in Runner.run_async.<locals>._run_with_trace.<locals>.execute(ctx)
#     537 async def execute(ctx: InvocationContext) -> AsyncGenerator[Event]:
#     538   async with Aclosing(ctx.agent.run_async(ctx)) as agen:
# --> 539     async for event in agen:
#     540       yield event
#
# File ~/repos/stage/ctc-workshop/.venv/lib/python3.11/site-packages/google/adk/agents/base_agent.py:295, in BaseAgent.run_async(self, parent_context)
#     292   return
#     294 async with Aclosing(self._run_async_impl(ctx)) as agen:
# --> 295   async for event in agen:
#     296     yield event
#     298 if ctx.end_invocation:
#
# File ~/repos/stage/ctc-workshop/.venv/lib/python3.11/site-packages/google/adk/agents/sequential_agent.py:78, in SequentialAgent._run_async_impl(self, ctx)
#      75     yield self._create_agent_state_event(ctx)
#      77 async with Aclosing(sub_agent.run_async(ctx)) as agen:
# ---> 78   async for event in agen:
#      79     yield event
#      80     if ctx.should_pause_invocation(event):
#
# File ~/repos/stage/ctc-workshop/.venv/lib/python3.11/site-packages/google/adk/agents/base_agent.py:295, in BaseAgent.run_async(self, parent_context)
#     292   return
#     294 async with Aclosing(self._run_async_impl(ctx)) as agen:
# --> 295   async for event in agen:
#     296     yield event
#     298 if ctx.end_invocation:
#
# File ~/repos/stage/ctc-workshop/.venv/lib/python3.11/site-packages/google/adk/agents/llm_agent.py:470, in LlmAgent._run_async_impl(self, ctx)
#     468 should_pause = False
#     469 async with Aclosing(self._llm_flow.run_async(ctx)) as agen:
# --> 470   async for event in agen:
#     471     self.__maybe_save_output_to_state(event)
#     472     yield event
#
# File ~/repos/stage/ctc-workshop/.venv/lib/python3.11/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:752, in BaseLlmFlow.run_async(self, invocation_context)
#     750 last_event = None
#     751 async with Aclosing(self._run_one_step_async(invocation_context)) as agen:
# --> 752   async for event in agen:
#     753     last_event = event
#     754     yield event
#
# File ~/repos/stage/ctc-workshop/.venv/lib/python3.11/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:829, in BaseLlmFlow._run_one_step_async(self, invocation_context)
#     818 model_response_event = Event(
#     819     id=Event.new_id(),
#     820     invocation_id=invocation_context.invocation_id,
#     821     author=invocation_context.agent.name,
#     822     branch=invocation_context.branch,
#     823 )
#     824 async with Aclosing(
#     825     self._call_llm_async(
#     826         invocation_context, llm_request, model_response_event
#     827     )
#     828 ) as agen:
# --> 829   async for llm_response in agen:
#     830     # Postprocess after calling the LLM.
#     831     async with Aclosing(
#     832         self._postprocess_async(
#     833             invocation_context,
#    (...)    837         )
#     838     ) as agen:
#     839       async for event in agen:
#     840         # Update the mutable event id to avoid conflict
#
# File ~/repos/stage/ctc-workshop/.venv/lib/python3.11/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:1186, in BaseLlmFlow._call_llm_async(self, invocation_context, llm_request, model_response_event)
#    1183           yield llm_response
#    1185 async with Aclosing(_call_llm_with_tracing()) as agen:
# -> 1186   async for event in agen:
#    1187     yield event
#
# File ~/repos/stage/ctc-workshop/.venv/lib/python3.11/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:1169, in BaseLlmFlow._call_llm_async.<locals>._call_llm_with_tracing()
#    1156 responses_generator = llm.generate_content_async(
#    1157     llm_request,
#    1158     stream=invocation_context.run_config.streaming_mode
#    1159     == StreamingMode.SSE,
#    1160 )
#    1161 async with Aclosing(
#    1162     self._run_and_handle_error(
#    1163         responses_generator,
#    (...)   1167     )
#    1168 ) as agen:
# -> 1169   async for llm_response in agen:
#    1170     trace_call_llm(
#    1171         invocation_context,
#    1172         model_response_event.id,
#    (...)   1175         span,
#    1176     )
#    1177     # Runs after_model_callback if it exists.
#
# File ~/repos/stage/ctc-workshop/.venv/lib/python3.11/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:1245, in BaseLlmFlow._run_and_handle_error(self, response_generator, invocation_context, llm_request, model_response_event)
#    1230 async def _run_and_handle_error(
#    1231     self,
#    1232     response_generator: AsyncGenerator[LlmResponse, None],
#    (...)   1235     model_response_event: Event,
#    1236 ) -> AsyncGenerator[LlmResponse, None]:
#    1237   async with Aclosing(
#    1238       _run_and_handle_error(
#    1239           response_generator,
#    (...)   1243       )
#    1244   ) as agen:
# -> 1245     async for response in agen:
#    1246       yield response
#
# File ~/repos/stage/ctc-workshop/.venv/lib/python3.11/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:389, in _run_and_handle_error(response_generator, invocation_context, llm_request, model_response_event)
#     387   yield error_response
#     388 else:
# --> 389   raise model_error
#
# File ~/repos/stage/ctc-workshop/.venv/lib/python3.11/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:374, in _run_and_handle_error(response_generator, invocation_context, llm_request, model_response_event)
#     370 async with Aclosing(response_generator) as agen:
#     371   with tracing.use_generate_content_span(
#     372       llm_request, invocation_context, model_response_event
#     373   ) as span:
# --> 374     async for llm_response in agen:
#     375       tracing.trace_generate_content_result(span, llm_response)
#     376       yield llm_response
#
# File ~/repos/stage/ctc-workshop/.venv/lib/python3.11/site-packages/google/adk/models/google_llm.py:264, in Gemini.generate_content_async(self, llm_request, stream)
#     259 except ClientError as ce:
#     260   if ce.code == 429:
#     261     # We expect running into a Resource Exhausted error to be a common
#     262     # client error that developers would run into. We enhance the messaging
#     263     # with possible fixes to this issue.
# --> 264     raise _ResourceExhaustedError(ce) from ce
#     266   raise ce
#
# _ResourceExhaustedError:
# On how to mitigate this issue, please refer to:
#
# https://google.github.io/adk-docs/agents/models/#error-code-429-resource_exhausted
#
#
# 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-3-flash\nPlease retry in 49.180331848s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-3-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '49s'}]}}

# %% [markdown]
# ### What just happened?
#
# ```
# User: "Generate a quarterly analytics report."
#   │
#   ▼
# ┌─────────────────────────────────────────────┐
# │           SequentialAgent (pipeline)         │
# │                                              │
# │  ┌──────────────┐   output_key:              │
# │  │ DataFetcher   │──→ fetched_data           │
# │  └──────────────┘         │                  │
# │                           ▼                  │
# │  ┌──────────────┐   output_key:              │
# │  │ Analyzer      │──→ analysis               │
# │  └──────────────┘         │                  │
# │                           ▼                  │
# │  ┌──────────────┐   output_key:              │
# │  │ ReportWriter  │──→ report                 │
# │  └──────────────┘                            │
# └─────────────────────────────────────────────┘
# ```
#
# Key ideas:
# - **`output_key`** saves each agent's final response into shared state (like a dict)
# - **`{fetched_data}`** in the next agent's instruction reads from that state
# - The `SequentialAgent` runs them in order — no LLM decides the routing
#
# ---

# %% [markdown]
# ## Part 2: Exercise — Build a Multi-Agent Analytics Helpdesk
#
# Now you'll build a **coordinator + specialist** pattern. Instead of a fixed pipeline, an LLM coordinator routes user queries to the right specialist sub-agent.
#
# ```
# User question
#   │
#   ▼
# ┌─────────────────────┐
# │  Coordinator Agent   │  ← LLM decides who to call
# │  (sub_agents=[...])  │
# └──┬──────────┬────────┘
#    │          │
#    ▼          ▼
# ┌──────┐  ┌──────────────┐
# │ SQL  │  │ Data Quality │
# │ Agent│  │ Agent        │
# └──────┘  └──────────────┘
# ```
#
# The coordinator is just an `Agent` with `sub_agents=[...]`. The model's instruction tells it when to delegate to which specialist.

# %% [markdown]
# ### Fake database for the exercise

# %%
TABLES = {
    "customers": [
        {"id": 1, "name": "Acme Corp", "segment": "Enterprise", "mrr": 12000},
        {"id": 2, "name": "StartupXYZ", "segment": "SMB", "mrr": 500},
        {"id": 3, "name": "MegaRetail", "segment": "Enterprise", "mrr": 25000},
        {"id": 4, "name": "LocalShop", "segment": "SMB", "mrr": 200},
        {"id": 5, "name": "TechGiant", "segment": "Enterprise", "mrr": 45000},
    ],
    "events": [
        {"customer_id": 1, "event": "login", "count": 340, "month": "2024-12"},
        {"customer_id": 1, "event": "export", "count": 45, "month": "2024-12"},
        {"customer_id": 2, "event": "login", "count": 12, "month": "2024-12"},
        {"customer_id": 3, "event": "login", "count": 580, "month": "2024-12"},
        {"customer_id": 3, "event": "export", "count": 120, "month": "2024-12"},
        {"customer_id": 4, "event": "login", "count": 3, "month": "2024-12"},
        {"customer_id": 5, "event": "login", "count": 890, "month": "2024-12"},
        {"customer_id": 5, "event": "export", "count": 200, "month": "2024-12"},
    ],
}

# %% [markdown]
# ### TODO 1: Define tools for the SQL Agent
#
# The SQL agent helps analysts query data. Create two tools:
# - `list_tables()` — returns available table names
# - `run_query(table: str, filter_field: str, filter_value: str)` — filters a table and returns matching rows
#
# Hint: Use the `TABLES` dict above. The "query" is just a Python dict filter — no real SQL needed.

# %%
# TODO 1: Define tools for the SQL Agent

def list_tables() -> str:
    """List all available database tables."""
    # TODO: Return the table names from TABLES
    pass


def run_query(table: str, filter_field: str, filter_value: str) -> str:
    """Query a table with an optional filter. Returns matching rows.

    Args:
        table: Name of the table to query (e.g. 'customers')
        filter_field: Column to filter on (e.g. 'segment')
        filter_value: Value to match (e.g. 'Enterprise')
    """
    # TODO: Look up the table in TABLES, filter rows where row[filter_field] matches filter_value,
    #       and return the matching rows as a string. Handle missing tables gracefully.
    pass

# %% [markdown]
# ### TODO 2: Define tools for the Data Quality Agent
#
# The data quality agent checks datasets for issues. Create two tools:
# - `check_missing_values(table: str)` — checks for None/empty values in any field
# - `check_duplicates(table: str, field: str)` — checks if any values in a field are repeated

# %%
# TODO 2: Define tools for the Data Quality Agent

def check_missing_values(table: str) -> str:
    """Check a table for missing or None values in any field. Returns a report of findings."""
    # TODO: Iterate through rows in TABLES[table], check each field for None or empty string,
    #       and return a summary (e.g. "No missing values" or "Row 2: field 'name' is missing")
    pass


def check_duplicates(table: str, field: str) -> str:
    """Check if any values in a specific field are duplicated.

    Args:
        table: Name of the table to check
        field: Column name to check for duplicates
    """
    # TODO: Collect all values for the given field, find duplicates, and return a report
    pass

# %% [markdown]
# ### TODO 3: Create the specialist sub-agents
#
# Create two `Agent` instances:
# - `sql_agent` — with the SQL tools and an instruction saying it helps run queries
# - `data_quality_agent` — with the quality tools and an instruction about checking data health

# %%
# TODO 3: Create specialist sub-agents

sql_agent = Agent(
    model="gemini-3-flash-preview",
    name="sql_agent",
    # TODO: Write an instruction telling this agent it's a SQL specialist that helps
    #       analysts query data. It should list tables first, then run queries.
    instruction="""
    """,
    tools=[],  # TODO: Add your SQL tools here
)

data_quality_agent = Agent(
    model="gemini-3-flash-preview",
    name="data_quality_agent",
    # TODO: Write an instruction telling this agent it's a data quality specialist
    #       that checks for missing values and duplicates.
    instruction="""
    """,
    tools=[],  # TODO: Add your data quality tools here
)

# %% [markdown]
# ### TODO 4: Create the coordinator agent
#
# The coordinator doesn't have tools — it has `sub_agents`. Its instruction tells the LLM when to route to each specialist.
#
# Key: Use `sub_agents=[...]` instead of `tools=[...]`.

# %%
# TODO 4: Create the coordinator agent

coordinator = Agent(
    model="gemini-3-flash-preview",
    name="analytics_helpdesk",
    # TODO: Write an instruction that tells the coordinator to:
    #       - Route data/query questions to sql_agent
    #       - Route quality/validation questions to data_quality_agent
    #       - Answer general analytics questions itself
    instruction="""
    """,
    sub_agents=[],  # TODO: Add your specialist agents here
)

# %% [markdown]
# ### TODO 5: Test with a user query
#
# Try different queries to see the coordinator route to different specialists:
# - `"Show me all enterprise customers"` → should go to SQL agent
# - `"Are there any data quality issues in the events table?"` → should go to data quality agent
# - `"What metrics should I track for churn?"` → coordinator answers directly

# %%
# TODO 5: Change this query to test different routing paths

runner = InMemoryRunner(agent=coordinator, app_name="analytics_helpdesk")
runner.auto_create_session = True

test_query = "Show me all enterprise customers"  # TODO: Try different queries!

user_content = types.Content(
    role="user",
    parts=[types.Part.from_text(text=test_query)],
)

final_text = ""
async for event in runner.run_async(user_id="user1", session_id="session1", new_message=user_content):
    if event.content and event.content.parts:
        for part in event.content.parts:
            if part.text:
                final_text = part.text

print(final_text)

# %% [markdown]
# ## Recap
#
# | Pattern | ADK Feature | You Built |
# |---|---|---|
# | **Sequential pipeline** | `SequentialAgent` + `output_key` | Analytics report generator |
# | **LLM-routed delegation** | `Agent` with `sub_agents` | Analytics helpdesk |
#
# Both patterns use the same building block — `Agent` with tools — but compose them differently. The ADK handles all the message passing and routing mechanics.
